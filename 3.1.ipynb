# %% [markdown]
# ### Section :3 - Conceptual Questions

# %% [markdown]
# Q-3.1 – Imagine that the boxes shown in the image have shiny metallic surfaces with widely varying colours and is laid out in artificially lit indoor space. The box contours will have high glare from the light source and reflections of adjacent boxes along their edges. What image pre-processing techniques will you adapt to ensure that these effects are minimized for further processing of such an image?

# %%
from IPython.display import Image
Image(filename='x.png', width=800,height=100)

# %% [markdown]
# ### To deal with glare and high intensity in the images :
#
# * We can use adaptive thresholding method to deal with high intensity images.
# Reference : http://docs.opencv.org/3.2.0/d7/d4d/tutorial_py_thresholding.html
#
# * Detection of high intensilty if they are localized and then removing the portion with surrounding pixels.
# Reference: http://dsp.stackexchange.com/a/1239
